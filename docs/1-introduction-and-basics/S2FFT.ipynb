# %%
import jax
import jax.random as jr
import jax_healpy as jhp

nside = 32
key = jr.key(0)
# Out:
# /lustre/fswork/projects/rech/tkc/commun/venv/pm/lib/python3.12/site-packages/jaxlib/plugin_support.py:91: RuntimeWarning: JAX plugin jax_cuda12_plugin version 0.10.1 is installed, but it is not compatible with the installed jaxlib version 0.10.0, so it will not be used.
#   warnings.warn(
# JAX is not using 64-bit precision. This will dramatically affect numerical precision at even moderate L.
# JAX is not using 64-bit precision. Results will diverge from healpy even at moderate nside and can overflow for nside > 8192. See the README on numerical precision.

# %%
npix = jhp.nside2npix(nside)
hp_map = jax.random.normal(key, (npix,))

# %%
jax.clear_caches()

# %%
# %time cuda_alms = jhp.map2alm(hp_map , method="jax_cuda").block_until_ready()
# Out:
# CPU times: user 2.03 s, sys: 302 ms, total: 2.33 s
# Wall time: 4.05 s

# %%
# %time jax_alms = jhp.map2alm(hp_map , method="jax").block_until_ready()
# Out:
# CPU times: user 14.8 s, sys: 1.33 s, total: 16.1 s
# Wall time: 21.2 s

# %%
# %timeit cuda_alms = jhp.map2alm(hp_map , method="jax_cuda").block_until_ready()
# Out:
# 17.7 ms ± 6.57 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit jax_alms = jhp.map2alm(hp_map , method="jax").block_until_ready()
# Out:
# 19.2 ms ± 9.91 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
print("finished all good")
# Out:
# finished all good
